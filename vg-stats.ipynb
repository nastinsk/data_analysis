# %% [markdown]
# # Lab 11 - Data Analysis
# ## vg-stats dataset
# ### 12/16/2019

# %%
import pandas as pd
import numpy as np

# %%
video_games_df = pd.read_csv('vgsales.csv')

# %%
video_games_df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ## Which company is the most common video game publisher?

# %%
common_publishers = video_games_df['Publisher'].mode()[0]

# %%
common_publishers
# Out:
# 'Electronic Arts'

# %%
video_games_df[video_games_df['Publisher'] == common_publishers]
# Out:
#         Rank                          Name Platform    Year       Genre  \
# 77        78                       FIFA 16      PS4  2015.0      Sports
# 82        83                FIFA Soccer 13      PS3  2012.0      Action
# 83        84                    The Sims 3       PC  2009.0  Simulation
# 92        93  Star Wars Battlefront (2015)      PS4  2015.0     Shooter
# 99       100                 Battlefield 3     X360  2011.0     Shooter
# ...      ...                           ...      ...     ...         ...
# 16339  16342    Command & Conquer Renegade       PC  2002.0     Shooter
# 16384  16387             Poker for Dummies       PC  2008.0        Misc
# 16413  16416      The Godfather (JP sales)     X360  2006.0      Action
# 16539  16542     Spore Galactic Adventures       PC  2009.0    Strategy
# 16554  16557             Psychic Detective       PS  1995.0   Adventure
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %% [markdown]
# ## What’s the most common platform?

# %%
common_platforms = video_games_df['Platform'].mode()[0]

# %%
common_platforms
# Out:
# 'DS'

# %% [markdown]
# ## What about the most common genre?

# %%
common_genre = video_games_df['Genre'].mode()[0]

# %%
common_genre
# Out:
# 'Action'

# %% [markdown]
# ## What are the top 20 highest grossing games?

# %%
sorted_by_gross = video_games_df.sort_values('Global_Sales', ascending=False)

# %%
sorted_by_gross.head(20)
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %% [markdown]
# ## For North American video game sales, what’s the median?

# %%
na_sales =  sorted_by_na_sales['NA_Sales']
sorted_by_na_sales = video_games_df.sort_values('NA_Sales', ascending=False)

# %%
na_sales_median = na_sales.median()

# %%
na_sales_median
# Out:
# 0.08

# %% [markdown]
# ## Provide a secondary output showing ‘about’ ten games surrounding the median sales output

# %%
median_index = (sorted_by_na_sales.shape[0] + 1) // 2

# %%
median_index
# Out:
# 8299

# %%
sorted_by_na_sales.iloc[median_index]
# Out:
# Rank                     9194
# Name            Dino Crisis 3
# Platform                   XB
# Year                     2003
# Genre                  Action
# Publisher              Capcom
# NA_Sales                 0.08
# EU_Sales                 0.03
# JP_Sales                 0.03
# Other_Sales                 0
# Global_Sales             0.14
# Name: 9192, dtype: object

# %%
sorted_by_na_sales.iloc[median_index - 5:  median_index + 6 ]
# Out:
#         Rank                                              Name Platform  \
# 10802  10804                Bladestorm: The Hundred Years' War     X360
# 9569    9571                             Batman: Arkham Knight       PC
# 8550    8552     Wakeboarding Unleashed Featuring Shaun Murray      PS2
# 10799  10801                                         Mind Quiz      PSP
# 9197    9199                      The Walking Dead: Season Two     XOne
# 9192    9194                                     Dino Crisis 3       XB
# 10181  10183                              Smash Court Tennis 3     X360
# 8802    8804  Disney's The Lion King: Simba's Mighty Adventure       PS
# 8724    8726                                            Driven      PS2
# 10793  10795                                      Glory Days 2       DS
# 10298  10300                    National Geographic Challenge!      Wii
#
#          Year      Genre                               Publisher  NA_Sales  \
# ...

# %% [markdown]
# ## For the top-selling game of all time, how many standard deviations above/below the mean are its sales for North America?

# %%
sorted_by_top_game = video_games_df.sort_values('Global_Sales', ascending=False)

# %%
sorted_by_top_game[:1]
# Out:
#    Rank        Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 0     1  Wii Sports      Wii  2006.0  Sports  Nintendo     41.49     29.02
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74

# %%
mean_sales = np.mean(sorted_by_top_game)

# %%
mean_sales = mean_sales['Global_Sales']

# %%
mean_sales
# Out:
# 0.5374406555006628

# %%
deviation_sales = np.std(sorted_by_top_game)

# %%
deviation_sales = deviation_sales['Global_Sales']

# %%
deviation_sales
# Out:
# 1.5549810910296606

# %%
# (Top Game global sales - mean for global sales) / deviation_sales

# %%
top_game_sales = sorted_by_top_game.loc[0]['Global_Sales']

# %%
top_game_sales
# Out:
# 82.74

# %%
result = ((top_game_sales - mean_sales) / deviation_sales)

# %%
result
# Out:
# 52.864025047447576

# %% [markdown]
# ## How does Nintendo Wii's average number of sales compare with all of the other platforms?

# %%
wii_data = video_games_df[video_games_df['Platform'] == 'Wii']

# %%
wii_data
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 7          8                                           Wii Play      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# ...      ...                                                ...      ...
# 16517  16520                       Teenage Mutant Ninja Turtles      Wii
# 16552  16555           Mahou Sensei Negima!? Neo-Pactio Fight!!      Wii
# 16573  16576                                Mini Desktop Racing      Wii
# 16574  16577  Yattaman Wii: BikkuriDokkiri Machine de Mou Ra...      Wii
# 16581  16584                                          Fit & Fun      Wii
#
#          Year     Genre                     Publisher  NA_Sales  EU_Sales  \
# ...

# %%
wii_mean_sales = np.mean(wii_data['Global_Sales'])

# %%
wii_mean_sales
# Out:
# 0.6994037735849057

# %%
all_mean_sales = np.mean(video_games_df['Global_Sales'])

# %%
all_mean_sales
# Out:
# 0.5374406555006628

# %%
all_max_sales = np.max(video_games_df['Global_Sales'])

# %%
all_max_sales
# Out:
# 82.74

# %%
all_min_sales = np.min(video_games_df['Global_Sales'])

# %%
all_min_sales
# Out:
# 0.01

# %%
### wii average price compare to all game average price:

# %%
result = wii_mean_sales - all_mean_sales

# %%
result
# Out:
# 0.1619631180842429

# %% [markdown]
# ## Display 10 oldest games from the dataset

# %%
sorted_by_year = video_games_df.sort_values('Year', ascending=True)

# %%
sorted_by_year.head(10)
# Out:
#       Rank             Name Platform    Year     Genre   Publisher  NA_Sales  \
# 6896  6898         Checkers     2600  1980.0      Misc       Atari      0.22
# 2669  2671           Boxing     2600  1980.0  Fighting  Activision      0.72
# 5366  5368          Freeway     2600  1980.0    Action  Activision      0.32
# 1969  1971         Defender     2600  1980.0      Misc       Atari      0.99
# 1766  1768          Kaboom!     2600  1980.0      Misc  Activision      1.07
# 6317  6319           Bridge     2600  1980.0      Misc  Activision      0.25
# 544    545  Missile Command     2600  1980.0   Shooter       Atari      2.56
# 258    259        Asteroids     2600  1980.0   Shooter       Atari      4.00
# 4025  4027       Ice Hockey     2600  1980.0    Sports  Activision      0.46
# 4517  4519     Barnstorming     2600  1981.0    Action  Activision      0.40
#
#       EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 6896      0.01       0.0         0.00          0.24
# ...

# %% [markdown]
# ## Display all Atari games

# %%
atari_games = video_games_df[video_games_df['Publisher'] == 'Atari']

# %%
atari_games
# Out:
#         Rank                                               Name Platform  \
# 89        90                                            Pac-Man     2600
# 223      224                                           Driver 2       PS
# 258      259                                          Asteroids     2600
# 428      429                                   Enter the Matrix      PS2
# 450      451                             Dragon Ball Z: Budokai      PS2
# ...      ...                                                ...      ...
# 16017  16020                             Unreal Tournament 2003       PC
# 16141  16144                                    Furious Karting       XB
# 16305  16308                   Duel Masters: Shadow of the Code      GBA
# 16348  16351  Dungeons & Dragons: Neverwinter Nights - Complete       PC
# 16393  16396                                  Alone in the Dark       PC
#
#          Year      Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %% [markdown]
# ## Display all Atari games with Global_Sales more than 1

# %%
atari_best_sells = atari_games[atari_games['Global_Sales'] > 3]

# %%
atari_best_sells
# Out:
#      Rank                    Name Platform    Year     Genre Publisher  \
# 89     90                 Pac-Man     2600  1982.0    Puzzle     Atari
# 223   224                Driver 2       PS  2000.0    Action     Atari
# 258   259               Asteroids     2600  1980.0   Shooter     Atari
# 428   429        Enter the Matrix      PS2  2003.0    Action     Atari
# 450   451  Dragon Ball Z: Budokai      PS2  2002.0  Fighting     Atari
#
#      NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 89       7.28      0.45      0.00         0.08          7.81
# 223      2.36      2.10      0.02         0.25          4.73
# 258      4.00      0.26      0.00         0.05          4.31
# 428      1.78      1.12      0.09         0.19          3.18
# 450      2.17      0.28      0.55         0.08          3.09
